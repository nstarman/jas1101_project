# %%
from jas1101finalproject.fit import Fit_by_GC_name

# %load_ext autoreload
# %autoreload 2

# %%
Fit_by_GC_name("NGC_6121_M_4")
# Out:
# Left:0.389  Right:0.911
# Opening new pool: # of CPU used: 3
# Run Nested Fitting for the image... Dim of params: 5
# iter: 5920 | batch: 10 | bound: 67 | nc: 1 | ncall: 31480 | eff(%): 18.806 | loglstar: -4036.805 < -4033.988 < -4034.658 | logz: -4039.418 +/-  0.124 | stop:  2.282
# Finish Fitting! Total time elapsed: 103 s
#
# Pool Closed.
# 1/2/3 sigma upper limit BH fraction: 0.000108/0.000444/0.00118

# %%
Fit_by_GC_name("NGC_6121_M_4")
# Out:
# Left:0.389  Right:0.911
# Opening new pool: # of CPU used: 3
# Run Nested Fitting for the image... Dim of params: 6
# iter: 6465 | batch: 10 | bound: 121 | nc: 4 | ncall: 44023 | eff(%): 14.686 | loglstar: -4036.680 < -4033.732 < -4034.635 | logz: -4040.370 +/-  0.137 | stop:  2.269
# Finish Fitting! Total time elapsed: 155 s
#
# Pool Closed.
# 1/2/3 sigma upper limit BH fraction: 0.00575/0.0402/0.082

# %%
Fit_by_GC_name("NGC_6656_M_22")
# Out:
# Left:0.489  Right:0.860
# Opening new pool: # of CPU used: 3
# Run Nested Fitting for the image... Dim of params: 6
# iter: 10000 | batch: 6 | bound: 58 | nc: 3 | ncall: 52886 | eff(%): 18.909 | loglstar: -2027.961 < -2026.632 < -2027.339 | logz: -2040.872 +/-  0.198 | stop:    nan
# Finish Fitting! Total time elapsed: 174 s
#
# Pool Closed.
# 1/2/3 sigma upper limit BH fraction: 0.000873/0.0139/0.0422

# %%
Fit_by_GC_name("NGC_6397")
# Out:
# Left:0.352  Right:0.780
# Opening new pool: # of CPU used: 3
# Run Nested Fitting for the image... Dim of params: 6
# iter: 10601 | batch: 0 | bound: 33 | nc: 1 | ncall: 50998 | eff(%): 20.787 | loglstar:   -inf < -5235.224 <    inf | logz: -5253.177 +/-  0.312 | dlogz:  0.006 >  0.609
# Finish Fitting! Total time elapsed: 182 s
#
# Pool Closed.
# 1/2/3 sigma upper limit BH fraction: 0.000443/0.00593/0.0191
